# %%
#--EXERSICE-1---
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
raw_sensor_data = []
base_time = datetime.datetime(2023, 1, 1, 11, 0, 0) # Changed year to something more recent and valid
for i in range(100):
    timestamp = base_time + datetime.timedelta(minutes = i * 10 + random.randint(0,4))
    timestamp_str = timestamp.strftime('%Y-%m-%d %H:%M:%S') # Added quotes here
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES) # Corrected 'choive' to 'choice'
    location = random.choice(LOCATIONS)
    min_val, max_val = READING_RANGES[device_type] # Corrected 'device_types' to 'device_type'
    value = round(random.uniform(min_val, max_val), 2)
    reading = (timestamp_str, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

print("\n--- Output Task 1.1 ---")
print("Total sensor readings:", len(raw_sensor_data))

print("\nFirst 5 Sensor Readings:")
for reading in raw_sensor_data[:5]:
    print(reading)






# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings =[]
for i in raw_sensor_data:
    if i[2] == 'Temperature_Sensor':
        # Corrected dictionary creation syntax from assignment to key-value pairs
        temperature_readings.append({'timestamp': i[0], 'device_id': i[1], 'location': i[3], 'temperature_celsius': i[4]})

print("\n--- Output Task 1.2 ---")
print("Total Temperature Readings:", len(temperature_readings))

print("\nFirst 5 Temperature Readings:")
for reading in temperature_readings[:5]:
    print(reading)



# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()
for i in raw_sensor_data:
    unique_locations.add(i[3])

print("\n--- Output Task 1.3 ---")
print("Unique Locations:")
print(unique_locations)

print("\nNumber of Unique Locations:", len(unique_locations))


# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {}
for dt in DEVICE_TYPES: # Changed variable name to avoid conflict with `i` in inner loop
    device_stats[dt] = (float("inf"), float("-inf"))
for j in raw_sensor_data:
    device_type = j[2]
    value = j[4]
    current_min, current_max = device_stats[device_type] # Corrected `device_stats[i]` to `device_stats[device_type]`
    current_min = min(current_min, value)
    current_max = max(current_max, value)
    device_stats[device_type] = (current_min, current_max) # Corrected `device_stats[i]` to `device_stats[device_type]`

print("\n--- Output Task 1.4 ---")
print("Device Statistics (Min, Max):")

for device, stats in device_stats.items():
    print(f"{device}: Min = {stats[0]}, Max = {stats[1]}")



# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

print("\n--- Output Task 1.5.1 ---")

print("\n10th to 20th Readings:")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th Reading:")
for reading in sliced_readings_2:
    print(reading)


# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
substring_1 = sample_string[6:18]
substring_2 = sample_string[6::-1]

print("\n--- Output Task 1.5.2 ---")
print("Original String:", sample_string)

print("Substring 'Programming':", substring_1)
print("Reverse of 'Python':", substring_2)

# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("\n--- Output Task 1.5.3 ---")
print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)

#--- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
def get_readings_by_location(reading_list, target_location):
    result = []
    for i in reading_list:
        if i[3] == target_location:
            result.append(i)
    return result

print("\n--- Output Task 2.1 ---")

lab1_readings = get_readings_by_location(raw_sensor_data, "Lab1")

print("Total Readings in Lab1:", len(lab1_readings))

print("\nFirst 5 Readings from Lab1:")
for reading in lab1_readings[:5]:
    print(reading)



# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
def calculate_average_temperature(temp_data_list):

    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for item in temp_data_list:
        total += item["temperature_celsius"]

    return total / len(temp_data_list)
print("\n--- Output Task 2.2 ---")

average_temp = calculate_average_temperature(temperature_readings)

print("Average Temperature:", round(average_temp, 2), "°C")


# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
def generate_report_line(reading_dict):
    timestamp = reading_dict["timestamp"]
    device_id = reading_dict["device_id"]
    location = reading_dict["location"]
    temperature_celsius = reading_dict["temperature_celsius"]
    # Added the return statement to complete the function
    return f"[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

print("\n--- Output Task 2.3 ---")

if temperature_readings:
    report = generate_report_line(temperature_readings[0])
    print(report)
else:
    print("No temperature readings available.")


# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")

print("\n--- Output Task 3.1 ---")
print("Current Working Directory:")
print(os.getcwd())

print("Reports Folder:", reports_dir)


# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

print("\n--- Output Task 3.2 ---")

print("First Timestamp:", first_timestamp_str)
print("Last Timestamp :", last_timestamp_str)

print("Duration:", duration)


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
random_values = []

for i in range(5):
    random_values.append(random.randint(100,200))

print(random_values)

print("\n--- Output Task 3.3 ---")

print("Random Values:")
print(random_values)

print("One value per line:")
for value in random_values:
    print(value)


# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

print("\n--- Output Task 4.1 ---")

print("Report File:", report_filename)

print("File Exists:", os.path.exists(report_filename))

print("File Size:", os.path.getsize(report_filename), "bytes")


# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
read_report_lines = []

try:
    with open(report_filename,"r") as f:
        read_report_lines = f.readlines()

    print("First 3 lines:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(e)

print("\n--- Output Task 4.2 ---")

print("Total Lines in Report:", len(read_report_lines))

print("\nComplete Report:")

for line in read_report_lines:
    print(line.strip())


print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")

#
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
#
# --- Output Task 1.1 ---
# Total sensor readings: 100
#
# First 5 Sensor Readings:
# ('2023-01-01 11:01:00', 'DEV001', 'Temperature_Sensor', 'Lab1', 24.6)
# ('2023-01-01 11:12:00', 'DEV002', 'Pressure_Sensor', 'Lab2', 1013.12)
# ('2023-01-01 11:23:00', 'DEV003', 'Temperature_Sensor', 'Lab2', 27.45)
# ('2023-01-01 11:31:00', 'DEV004', 'Pressure_Sensor', 'Lab1', 1015.89)
# ('2023-01-01 11:43:00', 'DEV005', 'Temperature_Sensor', 'Lab2', 21.29)
#
# --- Output Task 1.2 ---
# Total Temperature Readings: 30
#
# First 5 Temperature Readings:
# {'timestamp': '2023-01-01 11:01:00', 'device_id': 'DEV001', 'location': 'Lab1', 'temperature_celsius': 24.6}
# {'timestamp': '2023-01-01 11:23:00', 'device_id': 'DEV003', 'location': 'Lab2', 'temperature_celsius': 27.45}
# {'timestamp': '2023-01-01 11:43:00', 'device_id': 'DEV005', 'location': 'Lab2', 'temperature_celsius': 21.29}
# {'timestamp': '2023-01-01 12:13:00', 'device_id': 'DEV008', 'location': 'Lab2', 'temperature_celsius': 27.91}
# {'timestamp': '2023-01-01 12:40:00', 'device_id': 'DEV011', 'location': 'Lab2', 'temperature_celsius': 19.61}
#
# --- Output Task 1.3 ---
# Unique Locations:
# {'Lab2', 'Lab1', 'OfficeB', 'Warehouse', 'OfficeA'}
#
# Number of Unique Locations: 5
#
# --- Output Task 1.4 ---
# Device Statistics (Min, Max):
# Temperature_Sensor: Min = 18.0, Max = 29.71
# Humidity_Sensor: Min = 31.34, Max = 76.98
# Pressure_Sensor: Min = 983.45, Max = 1028.68
# Light_Sensor: Min = 118.16, Max = 825.57
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# --- Output Task 1.5.1 ---
#
# 10th to 20th Readings:
# ('2023-01-01 12:30:00', 'DEV010', 'Pressure_Sensor', 'Lab1', 1021.77)
# ('2023-01-01 12:40:00', 'DEV011', 'Temperature_Sensor', 'Lab2', 19.61)
# ('2023-01-01 12:54:00', 'DEV012', 'Pressure_Sensor', 'Lab1', 1006.06)
# ('2023-01-01 13:01:00', 'DEV013', 'Humidity_Sensor', 'Lab1', 50.48)
# ('2023-01-01 13:11:00', 'DEV014', 'Light_Sensor', 'OfficeB', 160.97)
# ('2023-01-01 13:22:00', 'DEV015', 'Humidity_Sensor', 'Lab2', 70.07)
# ('2023-01-01 13:30:00', 'DEV016', 'Pressure_Sensor', 'Warehouse', 993.62)
# ('2023-01-01 13:41:00', 'DEV017', 'Light_Sensor', 'OfficeA', 545.64)
# ('2023-01-01 13:51:00', 'DEV018', 'Humidity_Sensor', 'OfficeA', 31.45)
# ('2023-01-01 14:04:00', 'DEV019', 'Humidity_Sensor', 'Warehouse', 55.01)
# ('2023-01-01 14:12:00', 'DEV020', 'Temperature_Sensor', 'Lab2', 21.21)
#
# Every 5th Reading:
# ('2023-01-01 11:01:00', 'DEV001', 'Temperature_Sensor', 'Lab1', 24.6)
# ('2023-01-01 11:54:00', 'DEV006', 'Pressure_Sensor', 'Lab2', 1016.51)
# ('2023-01-01 12:40:00', 'DEV011', 'Temperature_Sensor', 'Lab2', 19.61)
# ('2023-01-01 13:30:00', 'DEV016', 'Pressure_Sensor', 'Warehouse', 993.62)
# ('2023-01-01 14:23:00', 'DEV021', 'Temperature_Sensor', 'Warehouse', 22.85)
# ('2023-01-01 15:11:00', 'DEV026', 'Pressure_Sensor', 'OfficeA', 1000.3)
# ('2023-01-01 16:02:00', 'DEV031', 'Temperature_Sensor', 'Warehouse', 18.5)
# ('2023-01-01 16:52:00', 'DEV036', 'Pressure_Sensor', 'Lab2', 1017.15)
# ('2023-01-01 17:43:00', 'DEV041', 'Temperature_Sensor', 'OfficeB', 24.51)
# ('2023-01-01 18:30:00', 'DEV046', 'Pressure_Sensor', 'Lab2', 1001.28)
# ('2023-01-01 19:20:00', 'DEV051', 'Humidity_Sensor', 'Lab1', 73.28)
# ('2023-01-01 20:10:00', 'DEV056', 'Temperature_Sensor', 'OfficeA', 28.87)
# ('2023-01-01 21:04:00', 'DEV061', 'Light_Sensor', 'Lab1', 382.12)
# ('2023-01-01 21:54:00', 'DEV066', 'Pressure_Sensor', 'OfficeB', 993.66)
# ('2023-01-01 22:42:00', 'DEV071', 'Temperature_Sensor', 'OfficeA', 19.57)
# ('2023-01-01 23:34:00', 'DEV076', 'Temperature_Sensor', 'OfficeB', 26.22)
# ('2023-01-02 00:23:00', 'DEV081', 'Temperature_Sensor', 'Lab2', 29.71)
# ('2023-01-02 01:11:00', 'DEV086', 'Light_Sensor', 'Lab2', 218.36)
# ('2023-01-02 02:01:00', 'DEV091', 'Light_Sensor', 'Warehouse', 415.64)
# ('2023-01-02 02:50:00', 'DEV096', 'Humidity_Sensor', 'OfficeA', 52.17)
#
# --- Output Task 1.5.2 ---
# Original String: PythonProgrammingIsFun
# Substring 'Programming': ProgrammingI
# Reverse of 'Python': PnohtyP
#
# --- Output Task 1.5.3 ---
# 5th Reading Device Type: Temperature_Sensor
# Device Type Suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
#
# --- Output Task 2.1 ---
# Total Readings in Lab1: 18
#
# First 5 Readings from Lab1:
# ('2023-01-01 11:01:00', 'DEV001', 'Temperature_Sensor', 'Lab1', 24.6)
# ('2023-01-01 11:31:00', 'DEV004', 'Pressure_Sensor', 'Lab1', 1015.89)
# ('2023-01-01 12:30:00', 'DEV010', 'Pressure_Sensor', 'Lab1', 1021.77)
# ('2023-01-01 12:54:00', 'DEV012', 'Pressure_Sensor', 'Lab1', 1006.06)
# ('2023-01-01 13:01:00', 'DEV013', 'Humidity_Sensor', 'Lab1', 50.48)
#
# --- Output Task 2.2 ---
# Average Temperature: 24.65 °C
#
# --- Output Task 2.3 ---
# [2023-01-01 11:01:00] Device DEV001 at Lab1: 24.6°C
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.
#
# --- Output Task 3.1 ---
# Current Working Directory:
# /content
# Reports Folder: sensor_reports
#
# Duration of data collection: 0 days, 16 hours, 30 minutes.
#
# --- Output Task 3.2 ---
# First Timestamp: 2023-01-01 11:01:00
# Last Timestamp : 2023-01-02 03:31:00
# Duration: 16:30:00
# [124, 179, 107, 118, 146]
#
# --- Output Task 3.3 ---
# Random Values:
# [124, 179, 107, 118, 146]
# One value per line:
# 124
# 179
# 107
# 118
# 146
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# --- Output Task 4.1 ---
# Report File: sensor_reports/temperature_report.txt
# File Exists: True
# File Size: 1686 bytes
# First 3 lines:
# [2023-01-01 11:01:00] Device DEV001 at Lab1: 24.6°C
# [2023-01-01 11:23:00] Device DEV003 at Lab2: 27.45°C
# [2023-01-01 11:43:00] Device DEV005 at Lab2: 21.29°C
#
# --- Output Task 4.2 ---
# Total Lines in Report: 30
#
# Complete Report:
# [2023-01-01 11:01:00] Device DEV001 at Lab1: 24.6°C
# [2023-01-01 11:23:00] Device DEV003 at Lab2: 27.45°C
# [2023-01-01 11:43:00] Device DEV005 at Lab2: 21.29°C
# [2023-01-01 12:13:00] Device DEV008 at Lab2: 27.91°C
# [2023-01-01 12:40:00] Device DEV011 at Lab2: 19.61°C
# [2023-01-01 14:12:00] Device DEV020 at Lab2: 21.21°C
# [2023-01-01 14:23:00] Device DEV021 at Warehouse: 22.85°C
# [2023-01-01 14:52:00] Device DEV024 at Warehouse: 25.21°C
# [2023-01-01 15:03:00] Device DEV025 at OfficeB: 18.48°C
# [2023-01-01 16:02:00] Device DEV031 at Warehouse: 18.5°C
# [2023-01-01 17:04:00] Device DEV037 at OfficeA: 28.46°C
# [2023-01-01 17:10:00] Device DEV038 at OfficeA: 27.69°C
# [2023-01-01 17:43:00] Device DEV041 at OfficeB: 24.51°C
# [2023-01-01 18:51:00] Device DEV048 at OfficeB: 28.37°C
# [2023-01-01 19:31:00] Device DEV052 at Warehouse: 18.0°C
# [2023-01-01 20:04:00] Device DEV055 at Warehouse: 28.58°C
# [2023-01-01 20:10:00] Device DEV056 at OfficeA: 28.87°C
# [2023-01-01 20:54:00] Device DEV060 at OfficeB: 20.21°C
# [2023-01-01 21:40:00] Device DEV065 at OfficeA: 23.61°C
# [2023-01-01 22:00:00] Device DEV067 at Lab2: 24.66°C
# [2023-01-01 22:42:00] Device DEV071 at OfficeA: 19.57°C
# [2023-01-01 23:23:00] Device DEV075 at Warehouse: 28.63°C
# [2023-01-01 23:34:00] Device DEV076 at OfficeB: 26.22°C
# [2023-01-01 23:52:00] Device DEV078 at Lab2: 26.66°C
# [2023-01-02 00:23:00] Device DEV081 at Lab2: 29.71°C
# [2023-01-02 00:32:00] Device DEV082 at Lab2: 26.88°C
# [2023-01-02 01:50:00] Device DEV090 at OfficeB: 22.86°C
# [2023-01-02 03:03:00] Device DEV097 at OfficeA: 29.46°C
# [2023-01-02 03:12:00] Device DEV098 at Lab1: 26.97°C
# [2023-01-02 03:31:00] Device DEV100 at OfficeA: 22.59°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
